# %%
import pandas as pd
df = pd.read_csv('toronto_temp.csv')
df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace=True)
df.head()
# Out:
#             max_temperature  month
# date
# 1938-10-25            15.00     10
# 1938-10-26            16.65     10
# 1938-10-27            15.90     10
# 1938-10-28            14.28     10
# 1938-10-29            12.86     10

# %%
import plotly.express as px
fig = px.line(df, x=df.index, y='max_temperature')
fig.show()

# %% [markdown]
# # Create a seasonal model which forecasts the daily temperature for the next 10 years.
# Plot the original data, the forecasts you create, and be prepared to explain which is the best model for the data.
